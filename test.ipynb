# %%
a = [1, 2, 3]

b = a

c = list(a)

a is b
# Out:
# True

# %%
{x for x in range(10) if x % 2 == 0}
# Out:
# {0, 2, 4, 6, 8}

# %%
a = {1, 2, 3, 4, 5}

b = {3, 4, 5, 6, 7, 8}

result = a & b

print(result)
# Out:
# {3, 4, 5}
