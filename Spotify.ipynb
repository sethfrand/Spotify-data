# %%
import os  #This allows access to environment variables
from dotenv import load_dotenv #this allows us to access the .env file
import spotipy # This is how you can connect to Spotify API
from spotipy.oauth2 import SpotifyOAuth #This is how to connect to Spotify API with OAuth
import pandas as pd #Pandas library for data manipulation
from datetime import datetime # used to convert some data
import time #used so that we can limit get requests

load_dotenv()

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=os.getenv("SPOTIPY_CLIENT_ID"),
    client_secret=os.getenv("SPOTIPY_CLIENT_SECRET"),
    redirect_uri="http://127.0.0.1:8080/callback",
    scope="playlist-read-private playlist-read-collaborative user-library-read",
    open_browser=True
))

def get_playlist_tracks(playlist_id, playlist_name):
    """Get all tracks from a playlist"""
    tracks_data = []

    print(f"Fetching tracks from '{playlist_name[:40]}'...", end=" ")

    try:
        # Get tracks with pagination
        results = sp.playlist_items(playlist_id, limit=100)
        tracks = results['items']

        while results['next']:
            results = sp.next(results)
            tracks.extend(results['items'])

        # Process each track
        for item in tracks:
            track = item.get('track')
            added_at = item.get('added_at')

            if track and track.get('id'):
                # Get all artist names
                artists = [artist['name'] for artist in track['artists']]
                artist_ids = [artist['id'] for artist in track['artists']]

                # Get genres from first artist
                try:
                    artist_info = sp.artist(artist_ids[0])
                    genres = ', '.join(artist_info.get('genres', []))
                except:
                    genres = ''

                track_info = {
                    'playlist_name': playlist_name,
                    'added_at': added_at,
                    'track_name': track['name'],
                    'artist': ', '.join(artists),
                    'artist_id': artist_ids[0] if artist_ids else '',
                    'album': track['album']['name'],
                    'album_type': track['album']['album_type'],
                    'release_date': track['album']['release_date'],
                    'duration_ms': track['duration_ms'],
                    'duration_min': round(track['duration_ms'] / 60000, 2),
                    'popularity': track['popularity'],
                    'is_explicit': track['explicit'],
                    'genres': genres,
                    'track_id': track['id'],
                    'track_url': track['external_urls']['spotify'],
                    'preview_url': track.get('preview_url', ''),
                }
                tracks_data.append(track_info)

        print(f"✓ {len(tracks_data)} tracks")
        return tracks_data

    except Exception as e:
        print(f"✗ Error: {e}")
        return []

# Main execution
try:
    # Get only the first 50 playlists
    print("Fetching your playlists...")
    results = sp.current_user_playlists(limit=50)
    all_playlists = results['items'][:60]  # Limit to exactly 50

    print(f"\nFound {len(all_playlists)} playlists (limited to 50)")
    print("="*60)

    # Show which playlists will be processed
    print("\nPlaylists to be processed:")
    for idx, playlist in enumerate(all_playlists, 1):
        print(f"{idx:2d}. {playlist['name'][:50]} ({playlist['tracks']['total']} tracks)")

    print("\n" + "="*60)
    print("Starting extraction...\n")

    # Process each playlist
    all_tracks = []
    successful_count = 0

    for idx, playlist in enumerate(all_playlists, 1):
        print(f"[{idx}/50] ", end="")

        tracks_data = get_playlist_tracks(playlist['id'], playlist['name'])

        if tracks_data:
            all_tracks.extend(tracks_data)
            successful_count += 1

        time.sleep(0.5)  # Rate limiting

    # Save to CSV
    if all_tracks:
        df = pd.DataFrame(all_tracks)

        # Generate filename with timestamp
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"spotify_top50_playlists_{timestamp}.csv"

        df.to_csv(filename, index=False, encoding='utf-8-sig')

        print("\n" + "="*60)
        print(f"✓ SUCCESS!")
        print(f"  • Total tracks: {len(df):,}")
        print(f"  • Playlists processed: {successful_count}/50")
        print(f"  • Average tracks per playlist: {len(df)//successful_count if successful_count > 0 else 0}")
        print(f"  • Filename: '{filename}'")

        print(f"\nPlaylist breakdown:")
        playlist_counts = df['playlist_name'].value_counts()
        for playlist, count in playlist_counts.items():
            print(f"  • {playlist[:45]}: {count} tracks")

        print(f"\nData summary:")
        print(f"  • Unique tracks: {df['track_id'].nunique():,}")
        print(f"  • Unique artists: {df['artist'].nunique():,}")
        print(f"  • Average popularity: {df['popularity'].mean():.1f}")
        print(f"  • Explicit tracks: {df['is_explicit'].sum()} ({df['is_explicit'].mean()*100:.1f}%)")
        print(f"  • Average duration: {df['duration_min'].mean():.2f} min")

        print(f"\nSample data (first 10 tracks):")
        sample_cols = ['playlist_name', 'track_name', 'artist', 'popularity', 'duration_min']
        print(df[sample_cols].head(10).to_string(index=False))

        print(f"\nTop 10 most popular tracks:")
        top_tracks = df.nlargest(10, 'popularity')[['track_name', 'artist', 'popularity']]
        print(top_tracks.to_string(index=False))

    else:
        print("\n No tracks could be processed from any playlist")

except Exception as e:
    print(f"\n Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Fetching your playlists...
#
# Found 50 playlists (limited to 50)
# ============================================================
#
# Playlists to be processed:
#  1. Studies (8 tracks)
#  2. My Playlist #117 (17 tracks)
#  3. Queue (33 tracks)
#  4. The Most Beautiful Piano Pieces (137 tracks)
#  5. Mind is a playground (6 tracks)
#  6. Русские песни 🇷🇺🪆❤️ (56 tracks)
#  7. Oldies Station (10 tracks)
#  8. My Playlist #113 (0 tracks)
#  9. Elise work out  (21 tracks)
# 10. Elise’s Playlist (324 tracks)
# 11. Yellow line (8 tracks)
# 12. My Playlist #109 (6 tracks)
# 13. The Shoo me playlist (35 tracks)
# 14. Psychological warfare (16 tracks)
# 15. Some Christmas  (21 tracks)
# 16. GOOBA (13 tracks)
# 17. Break up with myself (171 tracks)
# 18. The shoo me song (0 tracks)
# 19. First dance song ideas (19 tracks)
# 20. Reception dance party (17 tracks)
# 21. 👦 🌊  (89 tracks)
# 22. 80s Hits - Best of the 80s (81 tracks)
# 23. May STD 23 (75 tracks)
# 24. Ghost (8 tracks)
# 25. A love story (2) (25 tracks)
# 26. Lyrically beautiful (19 tracks)
# 27. This ones for Elise (21 tracks)
# 28. No reason to be sad other than the love of sad mus (2 tracks)
# 29. Up 🎈  (32 tracks)
# 30. Repeats for march (23 tracks)
# 31. itd (129 tracks)
# 32. studies (50 tracks)
# 33. lemons (10 tracks)
# 34. late studies (81 tracks)
# 35. Iris\stacy (13 tracks)
# 36. Workout pt.2 (50 tracks)
# 37. Workout pt.1  (5 tracks)
# 38. w/ people (55 tracks)
# 39. too slow (11 tracks)
# 40. a love story (29 tracks)
# 41. Tunez  (20 tracks)
# 42. is my life is falling apart or coming together? (85 tracks)
# 43. Wesołych Świąt (5 tracks)
# 44. 2022 (25 tracks)
# 45. Polish Christmas music (56 tracks)
# 46. PENATONIX CHRISTMAS  (33 tracks)
# 47. smile again (7 tracks)
# 48. Apologetic (12 tracks)
# 49. List of songs I can’t listen to  (123 tracks)
# 50. Ale siedzi (89 tracks)
#
# ============================================================
# Starting extraction...
#
# [1/50] Fetching tracks from 'Studies'... ✓ 8 tracks
# [2/50] Fetching tracks from 'My Playlist #117'... ✓ 17 tracks
# [3/50] Fetching tracks from 'Queue'... ✓ 33 tracks
# [50/50] Fetching tracks from 'Ale siedzi'... ✓ 89 tracks
#
# ============================================================
# ✓ SUCCESS!
#   • Total tracks: 2,179
#   • Playlists processed: 48/50
#   • Average tracks per playlist: 45
#   • Filename: 'spotify_top50_playlists_20251112_131904.csv'
#
# Playlist breakdown:
#   • Elise’s Playlist: 324 tracks
#   • Break up with myself: 171 tracks
#   • The Most Beautiful Piano Pieces: 137 tracks
#   • itd: 129 tracks
#   • List of songs I can’t listen to : 123 tracks
#   • Ale siedzi: 89 tracks
#   • 👦 🌊 : 89 tracks
#   • is my life is falling apart or coming togethe: 85 tracks
#   • late studies: 81 tracks
#   • 80s Hits - Best of the 80s: 81 tracks
#   • May STD 23: 75 tracks
#   • Polish Christmas music: 56 tracks
#   • Русские песни 🇷🇺🪆❤️: 56 tracks
#   • w/ people: 55 tracks
#   • Workout pt.2: 50 tracks
#   • studies: 50 tracks
#   • The Shoo me playlist: 35 tracks
#   • PENATONIX CHRISTMAS : 33 tracks
#   • Queue: 33 tracks
#   • Up 🎈 : 32 tracks
#   • a love story: 29 tracks
#   • 2022: 25 tracks
#   • A love story (2): 25 tracks
#   • Repeats for march: 23 tracks
#   • This ones for Elise: 21 tracks
#   • Elise work out : 21 tracks
#   • Some Christmas : 21 tracks
#   • Tunez : 20 tracks
#   • Lyrically beautiful: 19 tracks
#   • First dance song ideas: 19 tracks
#   • Reception dance party: 17 tracks
#   • My Playlist #117: 17 tracks
#   • Psychological warfare: 16 tracks
#   • Iris\stacy: 13 tracks
#   • GOOBA: 13 tracks
#   • Apologetic: 12 tracks
#   • too slow: 11 tracks
#   • lemons: 10 tracks
#   • Oldies Station: 9 tracks
#   • Studies: 8 tracks
#   • Ghost: 8 tracks
#   • Yellow line: 7 tracks
#   • smile again: 7 tracks
#   • My Playlist #109: 6 tracks
#   • Mind is a playground: 6 tracks
#   • Wesołych Świąt: 5 tracks
#   • Workout pt.1 : 5 tracks
#   • No reason to be sad other than the love of sa: 2 tracks
#
# Data summary:
#   • Unique tracks: 1,852
#   • Unique artists: 878
#   • Average popularity: 44.8
#   • Explicit tracks: 363 (16.7%)
#   • Average duration: 3.50 min
#
# Sample data (first 10 tracks):
#    playlist_name                 track_name            artist  popularity  duration_min
#          Studies    Mia & Sebastian’s Theme    Justin Hurwitz          71          1.63
#          Studies Glimpse of Us X La La Land       Andy Morris          51          4.06
#          Studies        Jacob and the Stone     Emile Mosseri          76          1.64
#          Studies     Can You Hear The Music  Ludwig Göransson          72          1.84
#          Studies      Interstellar on Piano       Andy Morris          59          2.32
#          Studies          Once Upon a Dream Invadable Harmony          63          1.01
#          Studies                     Idea 9    Gibran Alcocer          66          2.29
#          Studies             Jacob's Prayer     Emile Mosseri          59          1.58
# My Playlist #117         Kashmir - Remaster      Led Zeppelin          70          8.62
# My Playlist #117                    Survive     Lewis Capaldi          78          3.75
#
# Top 10 most popular tracks:
#            track_name            artist  popularity
#                  Iris The Goo Goo Dolls          92
#                  Iris The Goo Goo Dolls          92
# Every Breath You Take        The Police          91
#                Yellow          Coldplay          91
#       Sweater Weather The Neighbourhood          91
#   When I Was Your Man        Bruno Mars          88
#        Mr. Brightside       The Killers          88
#               Perfect        Ed Sheeran          88
#         The Scientist          Coldplay          88
#                  Numb       Linkin Park          88
